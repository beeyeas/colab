# %% [markdown]
# <a href="https://colab.research.google.com/github/beeyeas/colab/blob/main/WorldPopulationMapWorldBankData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wbgapi plotly pandas requests

import wbgapi as wb
import plotly.express as px
import pandas as pd
import requests
import json

def get_population_data(country_code='USA', indicator_code='SP.POP.TOTL'):
    """
    Fetches population data from the World Bank API and parses the JSON response.

    Args:
        country_code (str): The country code (e.g., 'USA').
        indicator_code (str): The indicator code (e.g., 'SP.POP.TOTL').

    Returns:
        int or None: The population value if found, otherwise None.
    """
    url = f"https://api.worldbank.org/v2/country/{country_code}/indicator/{indicator_code}?format=json"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
        data = response.json()

        # Extract population from the JSON response
        if data and len(data) > 1 and data[1]:
            population = int(data[1][0]['value'])
            return population
        else:
            print(f"No population data found for {country_code} and indicator {indicator_code}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except (KeyError, IndexError, json.JSONDecodeError) as e:
        print(f"Error parsing JSON data: {e}")
        return None

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population

# Create a DataFrame to store the data
data = []
for country in wb.economy.list():
    try:
        # Use the get_population_data function to get population
        country_code = country['id']
        population = get_population_data(country_code, indicator)

        if population is not None:  # Check if population data was found
            country_name = country['value']
            data.append({'country_name': country_name, 'population': population})
            print(f"Adding country {country_code} with data.", {country_name})
        else:
            print(f"Skipping country {country_code} due to missing data.")
    except Exception as e:
        print(f"Error processing country {country_code}: {e}")

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country_name',
    locationmode='country names',
    color='population',
    hover_name='country_name',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# Collecting wbgapi
#   Downloading wbgapi-1.0.12-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from wbgapi) (6.0.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from wbgapi) (0.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading wbgapi-1.0.12-py3-none-any.whl (36 kB)
# Installing collected packages: wbgapi
# Successfully installed wbgapi-1.0.12
# Adding country ABW with data. {'Aruba'}
# Adding country AFE with data. {'Africa Eastern and Southern'}
# Adding country AFG with data. {'Afghanistan'}
# Adding country AFW with data. {'Africa Western and Central'}
# Adding country AGO with data. {'Angola'}
# Adding country ALB with data. {'Albania'}
# Adding country AND with data. {'Andorra'}
# Adding country ARB with data. {'Arab World'}
# Adding country ARE with data. {'United Arab Emirates'}
# Adding country ARG with data. {'Argentina'}
# Adding country ARM with data. {'Armenia'}
# Adding country ASM with data. {'American Samoa'}
# Adding country ATG with data. {'Antigua and Barbuda'}
# Adding country AUS with data. {'Australia'}
# Adding country AUT with data. {'Austria'}
# Adding country AZE with data. {'Azerbaijan'}
# Adding country BDI with data. {'Burundi'}
# Adding country BEL with data. {'Belgium'}
# Adding country BEN with data. {'Benin'}
# Adding country BFA with data. {'Burkina Faso'}
# Adding country BGD with data. {'Bangladesh'}
# Adding country BGR with data. {'Bulgaria'}
# Adding country BHR with data. {'Bahrain'}
# Adding country BHS with data. {'Bahamas, The'}
# Adding country BIH with data. {'Bosnia and Herzegovina'}
# Adding country BLR with data. {'Belarus'}
# Adding country BLZ with data. {'Belize'}
# Adding country BMU with data. {'Bermuda'}
# Adding country BOL with data. {'Bolivia'}
# Adding country BRA with data. {'Brazil'}
# Adding country BRB with data. {'Barbados'}
# Adding country BRN with data. {'Brunei Darussalam'}
# Adding country BTN with data. {'Bhutan'}
# Adding country BWA with data. {'Botswana'}
# Adding country CAF with data. {'Central African Republic'}
# Adding country CAN with data. {'Canada'}
# Adding country CEB with data. {'Central Europe and the Baltics'}
# Adding country CHE with data. {'Switzerland'}
# Adding country CHI with data. {'Channel Islands'}
# Adding country CHL with data. {'Chile'}
# Adding country CHN with data. {'China'}
# Adding country CIV with data. {"Cote d'Ivoire"}
# Adding country CMR with data. {'Cameroon'}
# Adding country COD with data. {'Congo, Dem. Rep.'}
# Adding country COG with data. {'Congo, Rep.'}
# Adding country COL with data. {'Colombia'}
# Adding country COM with data. {'Comoros'}
# Adding country CPV with data. {'Cabo Verde'}
# Adding country CRI with data. {'Costa Rica'}
# Adding country CSS with data. {'Caribbean small states'}
# Adding country CUB with data. {'Cuba'}
# Adding country CUW with data. {'Curacao'}
# Adding country CYM with data. {'Cayman Islands'}
# Adding country CYP with data. {'Cyprus'}
# Adding country CZE with data. {'Czechia'}
# Adding country DEU with data. {'Germany'}
# Adding country DJI with data. {'Djibouti'}
# Adding country DMA with data. {'Dominica'}
# Adding country DNK with data. {'Denmark'}
# Adding country DOM with data. {'Dominican Republic'}
# Adding country DZA with data. {'Algeria'}
# Adding country EAP with data. {'East Asia & Pacific (excluding high income)'}
# Adding country EAR with data. {'Early-demographic dividend'}
# Adding country EAS with data. {'East Asia & Pacific'}
# Adding country ECA with data. {'Europe & Central Asia (excluding high income)'}
# Adding country ECS with data. {'Europe & Central Asia'}
# Adding country ECU with data. {'Ecuador'}
# Adding country EGY with data. {'Egypt, Arab Rep.'}
# Adding country EMU with data. {'Euro area'}
# Adding country ERI with data. {'Eritrea'}
# Adding country ESP with data. {'Spain'}
# Adding country EST with data. {'Estonia'}
# Adding country ETH with data. {'Ethiopia'}
# Adding country EUU with data. {'European Union'}
# Adding country FCS with data. {'Fragile and conflict affected situations'}
# Adding country FIN with data. {'Finland'}
# Adding country FJI with data. {'Fiji'}
# Adding country FRA with data. {'France'}
# Adding country FRO with data. {'Faroe Islands'}
# Adding country FSM with data. {'Micronesia, Fed. Sts.'}
# Adding country GAB with data. {'Gabon'}
# Adding country GBR with data. {'United Kingdom'}
# Adding country GEO with data. {'Georgia'}
# Adding country GHA with data. {'Ghana'}
# Adding country GIB with data. {'Gibraltar'}
# Adding country GIN with data. {'Guinea'}
# Adding country GMB with data. {'Gambia, The'}
# Adding country GNB with data. {'Guinea-Bissau'}
# Adding country GNQ with data. {'Equatorial Guinea'}
# Adding country GRC with data. {'Greece'}
# Adding country GRD with data. {'Grenada'}
# Adding country GRL with data. {'Greenland'}
# Adding country GTM with data. {'Guatemala'}
# Adding country GUM with data. {'Guam'}
# Adding country GUY with data. {'Guyana'}
# Adding country HIC with data. {'High income'}
# Adding country HKG with data. {'Hong Kong SAR, China'}
# Adding country HND with data. {'Honduras'}
# Adding country HPC with data. {'Heavily indebted poor countries (HIPC)'}
# Adding country HRV with data. {'Croatia'}
# Adding country HTI with data. {'Haiti'}
# Adding country HUN with data. {'Hungary'}
# Adding country IBD with data. {'IBRD only'}
# Adding country IBT with data. {'IDA & IBRD total'}
# Adding country IDA with data. {'IDA total'}
# Adding country IDB with data. {'IDA blend'}
# Adding country IDN with data. {'Indonesia'}
# Adding country IDX with data. {'IDA only'}
# Adding country IMN with data. {'Isle of Man'}
# Adding country IND with data. {'India'}
# Error processing country INX: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Adding country IRL with data. {'Ireland'}
# Adding country IRN with data. {'Iran, Islamic Rep.'}
# Adding country IRQ with data. {'Iraq'}
# Adding country ISL with data. {'Iceland'}
# Adding country ISR with data. {'Israel'}
# Adding country ITA with data. {'Italy'}
# Adding country JAM with data. {'Jamaica'}
# Adding country JOR with data. {'Jordan'}
# Adding country JPN with data. {'Japan'}
# Adding country KAZ with data. {'Kazakhstan'}
# Adding country KEN with data. {'Kenya'}
# Adding country KGZ with data. {'Kyrgyz Republic'}
# Adding country KHM with data. {'Cambodia'}
# Adding country KIR with data. {'Kiribati'}
# Adding country KNA with data. {'St. Kitts and Nevis'}
# Adding country KOR with data. {'Korea, Rep.'}
# Adding country KWT with data. {'Kuwait'}
# Adding country LAC with data. {'Latin America & Caribbean (excluding high income)'}
# Adding country LAO with data. {'Lao PDR'}
# Adding country LBN with data. {'Lebanon'}
# Adding country LBR with data. {'Liberia'}
# Adding country LBY with data. {'Libya'}
# Adding country LCA with data. {'St. Lucia'}
# Adding country LCN with data. {'Latin America & Caribbean'}
# Adding country LDC with data. {'Least developed countries: UN classification'}
# Adding country LIC with data. {'Low income'}
# Adding country LIE with data. {'Liechtenstein'}
# Adding country LKA with data. {'Sri Lanka'}
# Adding country LMC with data. {'Lower middle income'}
# Adding country LMY with data. {'Low & middle income'}
# Adding country LSO with data. {'Lesotho'}
# Adding country LTE with data. {'Late-demographic dividend'}
# Adding country LTU with data. {'Lithuania'}
# Adding country LUX with data. {'Luxembourg'}
# Adding country LVA with data. {'Latvia'}
# Adding country MAC with data. {'Macao SAR, China'}
# Adding country MAF with data. {'St. Martin (French part)'}
# Adding country MAR with data. {'Morocco'}
# Adding country MCO with data. {'Monaco'}
# Adding country MDA with data. {'Moldova'}
# Adding country MDG with data. {'Madagascar'}
# Adding country MDV with data. {'Maldives'}
# Adding country MEA with data. {'Middle East & North Africa'}
# Adding country MEX with data. {'Mexico'}
# Adding country MHL with data. {'Marshall Islands'}
# Adding country MIC with data. {'Middle income'}
# Adding country MKD with data. {'North Macedonia'}
# Adding country MLI with data. {'Mali'}
# Adding country MLT with data. {'Malta'}
# Adding country MMR with data. {'Myanmar'}
# Adding country MNA with data. {'Middle East & North Africa (excluding high income)'}
# Adding country MNE with data. {'Montenegro'}
# Adding country MNG with data. {'Mongolia'}
# Adding country MNP with data. {'Northern Mariana Islands'}
# Adding country MOZ with data. {'Mozambique'}
# Adding country MRT with data. {'Mauritania'}
# Adding country MUS with data. {'Mauritius'}
# Adding country MWI with data. {'Malawi'}
# Adding country MYS with data. {'Malaysia'}
# Adding country NAC with data. {'North America'}
# Adding country NAM with data. {'Namibia'}
# Adding country NCL with data. {'New Caledonia'}
# Adding country NER with data. {'Niger'}
# Adding country NGA with data. {'Nigeria'}
# Adding country NIC with data. {'Nicaragua'}
# Adding country NLD with data. {'Netherlands'}
# Adding country NOR with data. {'Norway'}
# Adding country NPL with data. {'Nepal'}
# Adding country NRU with data. {'Nauru'}
# Adding country NZL with data. {'New Zealand'}
# Adding country OED with data. {'OECD members'}
# Adding country OMN with data. {'Oman'}
# Adding country OSS with data. {'Other small states'}
# Adding country PAK with data. {'Pakistan'}
# Adding country PAN with data. {'Panama'}
# Adding country PER with data. {'Peru'}
# Adding country PHL with data. {'Philippines'}
# Adding country PLW with data. {'Palau'}
# Adding country PNG with data. {'Papua New Guinea'}
# Adding country POL with data. {'Poland'}
# Adding country PRE with data. {'Pre-demographic dividend'}
# Adding country PRI with data. {'Puerto Rico'}
# Adding country PRK with data. {"Korea, Dem. People's Rep."}
# Adding country PRT with data. {'Portugal'}
# Adding country PRY with data. {'Paraguay'}
# Adding country PSE with data. {'West Bank and Gaza'}
# Adding country PSS with data. {'Pacific island small states'}
# Adding country PST with data. {'Post-demographic dividend'}
# Adding country PYF with data. {'French Polynesia'}
# Adding country QAT with data. {'Qatar'}
# Adding country ROU with data. {'Romania'}
# Adding country RUS with data. {'Russian Federation'}
# Adding country RWA with data. {'Rwanda'}
# Adding country SAS with data. {'South Asia'}
# Adding country SAU with data. {'Saudi Arabia'}
# Adding country SDN with data. {'Sudan'}
# Adding country SEN with data. {'Senegal'}
# Adding country SGP with data. {'Singapore'}
# Adding country SLB with data. {'Solomon Islands'}
# Adding country SLE with data. {'Sierra Leone'}
# Adding country SLV with data. {'El Salvador'}
# Adding country SMR with data. {'San Marino'}
# Adding country SOM with data. {'Somalia'}
# Adding country SRB with data. {'Serbia'}
# Adding country SSA with data. {'Sub-Saharan Africa (excluding high income)'}
# Adding country SSD with data. {'South Sudan'}
# Adding country SSF with data. {'Sub-Saharan Africa'}
# Adding country SST with data. {'Small states'}
# Adding country STP with data. {'Sao Tome and Principe'}
# Adding country SUR with data. {'Suriname'}
# Adding country SVK with data. {'Slovak Republic'}
# Adding country SVN with data. {'Slovenia'}
# Adding country SWE with data. {'Sweden'}
# Adding country SWZ with data. {'Eswatini'}
# Adding country SXM with data. {'Sint Maarten (Dutch part)'}
# Adding country SYC with data. {'Seychelles'}
# Adding country SYR with data. {'Syrian Arab Republic'}
# Adding country TCA with data. {'Turks and Caicos Islands'}
# Adding country TCD with data. {'Chad'}
# Adding country TEA with data. {'East Asia & Pacific (IDA & IBRD countries)'}
# Adding country TEC with data. {'Europe & Central Asia (IDA & IBRD countries)'}
# Adding country TGO with data. {'Togo'}
# Adding country THA with data. {'Thailand'}
# Adding country TJK with data. {'Tajikistan'}
# Adding country TKM with data. {'Turkmenistan'}
# Adding country TLA with data. {'Latin America & the Caribbean (IDA & IBRD countries)'}
# Adding country TLS with data. {'Timor-Leste'}
# Adding country TMN with data. {'Middle East & North Africa (IDA & IBRD countries)'}
# Adding country TON with data. {'Tonga'}
# Adding country TSA with data. {'South Asia (IDA & IBRD)'}
# Adding country TSS with data. {'Sub-Saharan Africa (IDA & IBRD countries)'}
# Adding country TTO with data. {'Trinidad and Tobago'}
# Adding country TUN with data. {'Tunisia'}
# Adding country TUR with data. {'Turkiye'}
# Adding country TUV with data. {'Tuvalu'}
# Adding country TZA with data. {'Tanzania'}
# Adding country UGA with data. {'Uganda'}
# Adding country UKR with data. {'Ukraine'}
# Adding country UMC with data. {'Upper middle income'}
# Adding country URY with data. {'Uruguay'}
# Adding country USA with data. {'United States'}
# Adding country UZB with data. {'Uzbekistan'}
# Adding country VCT with data. {'St. Vincent and the Grenadines'}
# Adding country VEN with data. {'Venezuela, RB'}
# Adding country VGB with data. {'British Virgin Islands'}
# Adding country VIR with data. {'Virgin Islands (U.S.)'}
# Adding country VNM with data. {'Viet Nam'}
# Adding country VUT with data. {'Vanuatu'}
# Adding country WLD with data. {'World'}
# Adding country WSM with data. {'Samoa'}
# Adding country XKX with data. {'Kosovo'}
# Adding country YEM with data. {'Yemen, Rep.'}
# Adding country ZAF with data. {'South Africa'}
# Adding country ZMB with data. {'Zambia'}
# Adding country ZWE with data. {'Zimbabwe'}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7c1c20e3-40c8-4269-9811-b24f0d29dd78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c1c20e3-40c8-4269-9811-b24f0d29dd78")) {                    Plotly.newPlot(                        "7c1c20e3-40c8-4269-9811-b24f0d29dd78",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{location}\u003cbr\u003epopulation=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Aruba","Africa Eastern and Southern","Afghanistan","Africa Western and Central","Angola","Albania","Andorra","Arab World","United Arab Emirates","Argentina","Armenia","American Samoa","Antigua and Barbuda","Australia","Austria","Azerbaijan","Burundi","Belgium","Benin","Burkina Faso","Bangladesh","Bulgaria","Bahrain","Bahamas, The","Bosnia and Herzegovina","Belarus","Belize","Bermuda","Bolivia","Brazil","Barbados","Brunei Darussalam","Bhutan","Botswana","Central African Republic","Canada","Central Europe and the Baltics","Switzerland","Channel Islands","Chile","China","Cote d'Ivoire","Cameroon","Congo, Dem. Rep.","Congo, Rep.","Colombia","Comoros","Cabo Verde","Costa Rica","Caribbean small states","Cuba","Curacao","Cayman Islands","Cyprus","Czechia","Germany","Djibouti","Dominica","Denmark","Dominican Republic","Algeria","East Asia & Pacific (excluding high income)","Early-demographic dividend","East Asia & Pacific","Europe & Central Asia (excluding high income)","Europe & Central Asia","Ecuador","Egypt, Arab Rep.","Euro area","Eritrea","Spain","Estonia","Ethiopia","European Union","Fragile and conflict affected situations","Finland","Fiji","France","Faroe Islands","Micronesia, Fed. Sts.","Gabon","United Kingdom","Georgia","Ghana","Gibraltar","Guinea","Gambia, The","Guinea-Bissau","Equatorial Guinea","Greece","Grenada","Greenland","Guatemala","Guam","Guyana","High income","Hong Kong SAR, China","Honduras","Heavily indebted poor countries (HIPC)","Croatia","Haiti","Hungary","IBRD only","IDA & IBRD total","IDA total","IDA blend","Indonesia","IDA only","Isle of Man","India","Ireland","Iran, Islamic Rep.","Iraq","Iceland","Israel","Italy","Jamaica","Jordan","Japan","Kazakhstan","Kenya","Kyrgyz Republic","Cambodia","Kiribati","St. Kitts and Nevis","Korea, Rep.","Kuwait","Latin America & Caribbean (excluding high income)","Lao PDR","Lebanon","Liberia","Libya","St. Lucia","Latin America & Caribbean","Least developed countries: UN classification","Low income","Liechtenstein","Sri Lanka","Lower middle income","Low & middle income","Lesotho","Late-demographic dividend","Lithuania","Luxembourg","Latvia","Macao SAR, China","St. Martin (French part)","Morocco","Monaco","Moldova","Madagascar","Maldives","Middle East & North Africa","Mexico","Marshall Islands","Middle income","North Macedonia","Mali","Malta","Myanmar","Middle East & North Africa (excluding high income)","Montenegro","Mongolia","Northern Mariana Islands","Mozambique","Mauritania","Mauritius","Malawi","Malaysia","North America","Namibia","New Caledonia","Niger","Nigeria","Nicaragua","Netherlands","Norway","Nepal","Nauru","New Zealand","OECD members","Oman","Other small states","Pakistan","Panama","Peru","Philippines","Palau","Papua New Guinea","Poland","Pre-demographic dividend","Puerto Rico","Korea, Dem. People's Rep.","Portugal","Paraguay","West Bank and Gaza","Pacific island small states","Post-demographic dividend","French Polynesia","Qatar","Romania","Russian Federation","Rwanda","South Asia","Saudi Arabia","Sudan","Senegal","Singapore","Solomon Islands","Sierra Leone","El Salvador","San Marino","Somalia","Serbia","Sub-Saharan Africa (excluding high income)","South Sudan","Sub-Saharan Afri ...
