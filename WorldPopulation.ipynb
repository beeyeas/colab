# %% [markdown]
# <a href="https://colab.research.google.com/github/beeyeas/colab/blob/main/WorldPopulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Generate maps with all countries by population.\

import plotly.express as px
import pandas as pd

# Sample data (replace with your actual data)
data = {
    'country': ['USA', 'China', 'India', 'Brazil', 'Russia'],
    'population': [331002651, 1439323776, 1380004385, 212559417, 146238428]
}
df = pd.DataFrame(data)

# Create the choropleth map
fig = px.choropleth(
    df,
    locations='country',  # Column containing country names
    locationmode='country names',  # Specify location mode for country names
    color='population',  # Column containing population data
    hover_name='country',  # Column for hover text
    color_continuous_scale='Viridis',  # Choose a color scale
    title='World Population Map'
)

# Display the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install wbgapi

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        #population = wb.data.get(indicator=indicator, economy=country['id'], mrv=1)[0]['value']
        population = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]['value']
        data.append({'country': country['value'], 'population': population})
    except KeyError:
        # Handle cases where population data is not available for a country
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country',
    locationmode='country names',
    color='population',
    hover_name='country',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /usr/lib/python3.11/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.11/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.11/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
# !pip install wbgapi

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # Check if the country is an aggregate economy like "Not classified"
        if country['aggregate']:
            continue  # Skip aggregate economies
        population = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]['value']
        data.append({'country': country['value'], 'population': population})
    except (KeyError, IndexError, wb.APIError):
        # Handle cases where population data is not available for a country
        # or if the API returns an error.
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country',
    locationmode='country names',
    color='population',
    hover_name='country',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-7b398ae6bf2b> in <cell line: 0>()
#      26
#      27 # Create the choropleth map using Plotly Express
# ---> 28 fig = px.choropleth(
#      29     df,
#      30     locations='country',
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1089     colored region mark on a map.
#    1090     """
# -> 1091     return make_figure(
# ...

# %%
# !pip install wbgapi

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # Check if the country is an aggregate economy like "Not classified"
        # or if it's a region (e.g., 'SSF') or income group (e.g., 'HIC')
        if country['aggregate'] or country['region'] or country['incomeLevel']:
            continue  # Skip these

        population = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]['value']
        data.append({'country': country['value'], 'population': population})
    except (KeyError, IndexError, wb.APIError):
        # Handle cases where population data is not available for a country
        # or if the API returns an error.
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country',
    locationmode='country names',
    color='population',
    hover_name='country',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ab37b75bb0bc> in <cell line: 0>()
#      28
#      29 # Create the choropleth map using Plotly Express
# ---> 30 fig = px.choropleth(
#      31     df,
#      32     locations='country',
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1089     colored region mark on a map.
#    1090     """
# -> 1091     return make_figure(
# ...

# %%
# !pip install wbgapi

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # Check if the country is an aggregate economy like "Not classified"
        # or if it's a region (e.g., 'SSF') or income group (e.g., 'HIC')
        # Instead of skipping all these, we only skip aggregates
        if country['aggregate']:
            continue  # Skip aggregate economies

        population = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]['value']
        data.append({'country': country['value'], 'population': population})
    except (KeyError, IndexError, wb.APIError):
        # Handle cases where population data is not available for a country
        # or if the API returns an error.
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country',
    locationmode='country names',
    color='population',
    hover_name='country',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-45b9916f6be9> in <cell line: 0>()
#      29
#      30 # Create the choropleth map using Plotly Express
# ---> 31 fig = px.choropleth(
#      32     df,
#      33     locations='country',
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1089     colored region mark on a map.
#    1090     """
# -> 1091     return make_figure(
# ...

# %%
# !pip install wbgapi

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # Check if the country is an aggregate economy like "Not classified"
        # or if it's a region (e.g., 'SSF') or income group (e.g., 'HIC')
        # Instead of skipping all these, we only skip aggregates
        # MODIFICATION: Removed the condition that was skipping all countries
        # if country['aggregate']:
        #     continue  # Skip aggregate economies

        population = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]['value']
        data.append({'country': country['value'], 'population': population})
    except (KeyError, IndexError, wb.APIError):
        # Handle cases where population data is not available for a country
        # or if the API returns an error.
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country',
    locationmode='country names',
    color='population',
    hover_name='country',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-ef587bde891a> in <cell line: 0>()
#      30
#      31 # Create the choropleth map using Plotly Express
# ---> 32 fig = px.choropleth(
#      33     df,
#      34     locations='country',
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1089     colored region mark on a map.
#    1090     """
# -> 1091     return make_figure(
# ...

# %%
# !pip install wbgapi

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # Check if the country is an aggregate economy like "Not classified"
        # or if it's a region (e.g., 'SSF') or income group (e.g., 'HIC')
        # Instead of skipping all these, we only skip aggregates
        # MODIFICATION: Removed the condition that was skipping all countries
        # if country['aggregate']:
        #     continue  # Skip aggregate economies

        # MODIFICATION: Access the country name and population using the correct keys
        population = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]['value']

        # Check if country name or population is empty/None
        if country['value'] and population:
            data.append({'country': country['value'], 'population': population})
            print(f"Adding country {country['id']} with data." ,{country['value']})
        else:
            print(f"Skipping country {country['id']} due to missing data.")
    except (KeyError, IndexError, wb.APIError) as e:
        # Handle cases where population data is not available for a country
        # or if the API returns an error.
        print(f"Error processing country {country['id']}: {e}")
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country',
    locationmode='country names',
    color='population',
    hover_name='country',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# Error processing country ABW: 0
# Error processing country AFE: 0
# Error processing country AFG: 0
# Error processing country AFW: 0
# Error processing country AGO: 0
# Error processing country ALB: 0
# Error processing country AND: 0
# Error processing country ARB: 0
# Error processing country ARE: 0
# Error processing country ARG: 0
# Error processing country ARM: 0
# Error processing country ASM: 0
# Error processing country ATG: 0
# Error processing country AUS: 0
# Error processing country AUT: 0
# Error processing country AZE: 0
# Error processing country BDI: 0
# Error processing country BEL: 0
# Error processing country BEN: 0
# Error processing country BFA: 0
# Error processing country BGD: 0
# Error processing country BGR: 0
# Error processing country BHR: 0
# Error processing country BHS: 0
# Error processing country BIH: 0
# Error processing country BLR: 0
# Error processing country BLZ: 0
# Error processing country BMU: 0
# Error processing country BOL: 0
# ...

# %%
# !pip install wbgapi

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # MODIFICATION: Access the country name and population using the correct keys
        population = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]['value']

        # Check if country name or population is empty/None
        if country['value'] and population:
            # MODIFICATION: Use 'country_name' for the country column
            data.append({'country_name': country['value'], 'population': population})
            print(f"Adding country {country['id']} with data." ,{country['value']})
        else:
            print(f"Skipping country {country['id']} due to missing data.")
    except (KeyError, IndexError, wb.APIError) as e:
        # Handle cases where population data is not available for a country
        # or if the API returns an error.
        #print(f"Error processing country {country['id']}: {e}")
        pass
print(f"Data collection completed. Total countries processed: {len(data)}")
df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country_name',  # MODIFICATION: Use 'country_name' for locations
    locationmode='country names',
    color='population',
    hover_name='country_name',  # MODIFICATION: Use 'country_name' for hover_name
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# Error processing country ABW: 0
# Error processing country AFE: 0
# Error processing country AFG: 0
# Error processing country AFW: 0
# Error processing country AGO: 0
# Error processing country ALB: 0
# Error processing country AND: 0
# Error processing country ARB: 0
# Error processing country ARE: 0
# Error processing country ARG: 0
# Error processing country ARM: 0
# Error processing country ASM: 0
# Error processing country ATG: 0
# Error processing country AUS: 0
# Error processing country AUT: 0
# Error processing country AZE: 0
# Error processing country BDI: 0
# Error processing country BEL: 0
# Error processing country BEN: 0
# Error processing country BFA: 0
# Error processing country BGD: 0
# Error processing country BGR: 0
# Error processing country BHR: 0
# Error processing country BHS: 0
# Error processing country BIH: 0
# Error processing country BLR: 0
# Error processing country BLZ: 0
# Error processing country BMU: 0
# Error processing country BOL: 0
# ...

# %%
# !pip install wbgapi
import wbgapi as wb
import plotly.express as px
import pandas as pd
import xml.etree.ElementTree as ET

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # Get the XML response as a string
        xml_response = wb.data.get(series=indicator, economy=country['id'], mrv=1, output_type='xml')

        # Parse the XML response
        root = ET.fromstring(xml_response)

        # Extract country name and population
        country_name = country['value']

        # Find the <wb:value> element (population)
        population_element = root.find('.//wb:value', namespaces={'wb': 'http://www.worldbank.org'})

        # Extract the population value if found
        if population_element is not None:
            population = population_element.text
            data.append({'country_name': country_name, 'population': int(population)})
            print(f"Adding country {country['id']} with data.", {country_name})
        else:
            print(f"Skipping country {country['id']} due to missing data.")

    except (KeyError, IndexError, wb.APIError, ET.ParseError) as e:
        # Handle cases where population data is not available or if there's an error
        print(f"Error processing country {country['id']}: {e}")
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country_name',
    locationmode='country names',
    color='population',
    hover_name='country_name',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# Error processing country ABW: 'output_type is not a concept in database 2'
# Error processing country AFE: 'output_type is not a concept in database 2'
# Error processing country AFG: 'output_type is not a concept in database 2'
# Error processing country AFW: 'output_type is not a concept in database 2'
# Error processing country AGO: 'output_type is not a concept in database 2'
# Error processing country ALB: 'output_type is not a concept in database 2'
# Error processing country AND: 'output_type is not a concept in database 2'
# Error processing country ARB: 'output_type is not a concept in database 2'
# Error processing country ARE: 'output_type is not a concept in database 2'
# Error processing country ARG: 'output_type is not a concept in database 2'
# Error processing country ARM: 'output_type is not a concept in database 2'
# Error processing country ASM: 'output_type is not a concept in database 2'
# ...

# %%
# !pip install wbgapi
import wbgapi as wb
import plotly.express as px
import pandas as pd
import xml.etree.ElementTree as ET

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population
countries = wb.economy.list()  # Get a list of all countries

# Create a DataFrame to store the data
data = []
for country in countries:
    try:
        # Get the population data as a dictionary (JSON format)
        population_data = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]
        print(f"Population data for {country['id']}: {population_data}")
        # Extract country name and population
        country_name = country['value']
        population = population_data['value']

        # Append data to the list
        data.append({'country_name': country_name, 'population': int(population)})
        print(f"Adding country {country['id']} with data.", {country_name})

    except (KeyError, IndexError, wb.APIError) as e:
        # Handle cases where population data is not available or if there's an error
        #print(f"Error processing country {country['id']}: {e}")
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country_name',
    locationmode='country names',
    color='population',
    hover_name='country_name',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-eb39ab83dc06> in <cell line: 0>()
#      32
#      33 # Create the choropleth map using Plotly Express
# ---> 34 fig = px.choropleth(
#      35     df,
#      36     locations='country_name',
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1089     colored region mark on a map.
#    1090     """
# -> 1091     return make_figure(
# ...

# %%
# !pip install wbgapi plotly pandas

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population

# Create a DataFrame to store the data
data = []
for country in wb.economy.list():
    try:
        # Get the population data for the most recent value
        population_data = wb.data.fetch(indicator, country['id'], time='MRV')
        print(f)
        if population_data:
            country_name = country['value']
            population = int(population_data[0]['value'])  # Convert to int

            data.append({'country_name': country_name, 'population': population})
            print(f"Adding country {country['id']} with data: {country_name}")
        else:
            print(f"No population data for {country['id']}: {country['value']}")

    except Exception as e:
        print(f"Error processing country {country['id']} ({country['value']}): {e}")

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country_name',
    locationmode='country names',
    color='population',
    hover_name='country_name',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Show the map. This will work in environments like Jupyter notebooks
fig.show()
# Out:
# ...
# Error processing country ABW (Aruba): 'generator' object is not subscriptable
# Error processing country AFE (Africa Eastern and Southern): 'generator' object is not subscriptable
# Error processing country AFG (Afghanistan): 'generator' object is not subscriptable
# Error processing country AFW (Africa Western and Central): 'generator' object is not subscriptable
# Error processing country AGO (Angola): 'generator' object is not subscriptable
# Error processing country ALB (Albania): 'generator' object is not subscriptable
# Error processing country AND (Andorra): 'generator' object is not subscriptable
# Error processing country ARB (Arab World): 'generator' object is not subscriptable
# Error processing country ARE (United Arab Emirates): 'generator' object is not subscriptable
# Error processing country ARG (Argentina): 'generator' object is not subscriptable
# Error processing country ARM (Armenia): 'generator' object is not subscriptable
# ...

# %%
# !pip install wbgapi plotly pandas

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population

# Create a DataFrame to store the data
data = []
for country in wb.economy.list():
    try:
        # Get the population data for the most recent value
        population_data = wb.data.fetch(indicator, country['id'], time='MRV')
        # Convert the generator to a list to access elements by index
        population_data_list = list(population_data)
        if population_data_list:
            country_name = country['value']
            population = int(population_data_list[0]['value'])  # Access using index 0

            # Use 'country_name' as the key for the country column
            data.append({'country_name': country_name, 'population': population})
            print(f"Adding country {country['id']} with data: {country_name}")
        else:
            print(f"No population data for {country['id']}: {country['value']}")

    except Exception as e:
        print(f"Error processing country {country['id']} ({country['value']}): {e}")

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
#fig = px.choropleth(
#    df,
#    locations='country_name',  # Use 'country_name' for locations
#    locationmode='country names',
#    color='population',
#    hover_name='country_name',  # Use 'country_name' for hover_name
#    color_continuous_scale='Viridis',
#    title='World Population Map (Data from World Bank)'
#)

# Show the map. This will work in environments like Jupyter notebooks
#fig.show()
# Out:
# ...
# Error processing country ABW (Aruba): APIError: JSON decoding error (https://api.worldbank.org/v2/en/sources/2/series/SP.POP.TOTL/country/ABW/time/MRV?per_page=1000&page=1&format=json)
# Error processing country AFE (Africa Eastern and Southern): APIError: JSON decoding error (https://api.worldbank.org/v2/en/sources/2/series/SP.POP.TOTL/country/AFE/time/MRV?per_page=1000&page=1&format=json)
# Error processing country AFG (Afghanistan): APIError: JSON decoding error (https://api.worldbank.org/v2/en/sources/2/series/SP.POP.TOTL/country/AFG/time/MRV?per_page=1000&page=1&format=json)
# Error processing country AFW (Africa Western and Central): APIError: JSON decoding error (https://api.worldbank.org/v2/en/sources/2/series/SP.POP.TOTL/country/AFW/time/MRV?per_page=1000&page=1&format=json)
# Error processing country AGO (Angola): APIError: JSON decoding error (https://api.worldbank.org/v2/en/sources/2/series/SP.POP.TOTL/country/AGO/time/MRV?per_page=1000&page=1&format=json)
# ...

# %%
# !pip install wbgapi plotly pandas

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population

# Create a DataFrame to store the data
data = []
for country in wb.economy.list():
    try:
        # Get the population data as a dictionary (JSON format)
        population_data = wb.data.get(series=indicator, economy=country['id'], mrv=1)[0]
        print(f"Population data for {country['id']}: {population_data}")
        # Extract country name and population
        country_name = country['value']
        population = population_data['value']

        # Append data to the list
        data.append({'country_name': country_name, 'population': int(population)})
        print(f"Adding country {country['id']} with data.", {country_name})

    except (KeyError, IndexError, wb.APIError) as e:
        # Handle cases where population data is not available or if there's an error
        #print(f"Error processing country {country['id']}: {e}")
        pass

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country_name',
    locationmode='country names',
    color='population',
    hover_name='country_name',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-03e06dea0866> in <cell line: 0>()
#      31
#      32 # Create the choropleth map using Plotly Express
# ---> 33 fig = px.choropleth(
#      34     df,
#      35     locations='country_name',
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1089     colored region mark on a map.
#    1090     """
# -> 1091     return make_figure(
# ...

# %%
# !pip install wbgapi plotly pandas requests

import wbgapi as wb
import plotly.express as px
import pandas as pd
import requests
import json

def get_population_data(country_code='USA', indicator_code='SP.POP.TOTL'):
    """
    Fetches population data from the World Bank API and parses the JSON response.

    Args:
        country_code (str): The country code (e.g., 'USA').
        indicator_code (str): The indicator code (e.g., 'SP.POP.TOTL').

    Returns:
        int or None: The population value if found, otherwise None.
    """
    url = f"https://api.worldbank.org/v2/country/{country_code}/indicator/{indicator_code}?format=json"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
        data = response.json()

        # Extract population from the JSON response
        if data and len(data) > 1 and data[1]:
            population = int(data[1][0]['value'])
            return population
        else:
            print(f"No population data found for {country_code} and indicator {indicator_code}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except (KeyError, IndexError, json.JSONDecodeError) as e:
        print(f"Error parsing JSON data: {e}")
        return None

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population

# Create a DataFrame to store the data
data = []
for country in wb.economy.list():
    try:
        # Use the get_population_data function to get population
        country_code = country['id']
        population = get_population_data(country_code, indicator)

        if population is not None:  # Check if population data was found
            country_name = country['value']
            data.append({'country_name': country_name, 'population': population})
            print(f"Adding country {country_code} with data.", {country_name})
        else:
            print(f"Skipping country {country_code} due to missing data.")
    except Exception as e:
        print(f"Error processing country {country_code}: {e}")

df = pd.DataFrame(data)

# Create the choropleth map using Plotly Express
fig = px.choropleth(
    df,
    locations='country_name',
    locationmode='country names',
    color='population',
    hover_name='country_name',
    color_continuous_scale='Viridis',
    title='World Population Map (Data from World Bank)'
)

# Display the map
fig.show()
# Out:
# ...
# Adding country ABW with data. {'Aruba'}
# Adding country AFE with data. {'Africa Eastern and Southern'}
# Adding country AFG with data. {'Afghanistan'}
# Adding country AFW with data. {'Africa Western and Central'}
# Adding country AGO with data. {'Angola'}
# Adding country ALB with data. {'Albania'}
# Adding country AND with data. {'Andorra'}
# Adding country ARB with data. {'Arab World'}
# Adding country ARE with data. {'United Arab Emirates'}
# Adding country ARG with data. {'Argentina'}
# Adding country ARM with data. {'Armenia'}
# Adding country ASM with data. {'American Samoa'}
# Adding country ATG with data. {'Antigua and Barbuda'}
# Adding country AUS with data. {'Australia'}
# Adding country AUT with data. {'Austria'}
# Adding country AZE with data. {'Azerbaijan'}
# Adding country BDI with data. {'Burundi'}
# Adding country BEL with data. {'Belgium'}
# Adding country BEN with data. {'Benin'}
# Adding country BFA with data. {'Burkina Faso'}
# ...

# %%
# !pip install requests

import requests
import json

def get_population_data(country_code='USA', indicator_code='SP.POP.TOTL'):
    """
    Fetches population data from the World Bank API and parses the JSON response.

    Args:
        country_code (str): The country code (e.g., 'USA').
        indicator_code (str): The indicator code (e.g., 'SP.POP.TOTL').

    Returns:
        int or None: The population value if found, otherwise None.
    """
    url = f"https://api.worldbank.org/v2/country/{country_code}/indicator/{indicator_code}?format=json"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
        data = response.json()

        # Extract population from the JSON response
        if data and len(data) > 1 and data[1]:
            population = int(data[1][0]['value'])
            return population
        else:
            print(f"No population data found for {country_code} and indicator {indicator_code}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except (KeyError, IndexError, json.JSONDecodeError) as e:
        print(f"Error parsing JSON data: {e}")
        return None

# Example usage
population = get_population_data()
if population:
    print(f"Population of USA: {population}")
# Out:
# ...
# Population of USA: 334914895

# %%
# !pip install wbgapi plotly pandas

import wbgapi as wb
import plotly.express as px
import pandas as pd

# Fetch population data from World Bank
indicator = 'SP.POP.TOTL'  # Indicator code for total population

# Create a DataFrame to store the data
data = []
for country in wb.economy.list():
    try:
        # Get the population data as a dictionary (JSON format)
        population_data = wb.data.get(series=indicator, economy=country['id'], mrv=1)
        # Check if population_data is not empty
        if population_data:
            population = population_data[0]['value']
            country_name = country['value']

            # Append data to the list
            data.append({'country_name': country_name, 'population': int(population)})
            print(f"Adding country {country['id']} with data.", {country_name})
        else:
            print(f"Skipping country {country['id']} due to missing data.")

    except (KeyError, IndexError, wb.APIError) as e:
        # Handle cases where population data is not available or if there's an error
        print(f"Error processing country {country['id']}: {e}")

df = pd.DataFrame(data)
# Out:
# ...
# Error processing country ABW: 0
# Error processing country AFE: 0
# Error processing country AFG: 0
# Error processing country AFW: 0
# Error processing country AGO: 0
# Error processing country ALB: 0
# Error processing country AND: 0
# Error processing country ARB: 0
# Error processing country ARE: 0
# Error processing country ARG: 0
# Error processing country ARM: 0
# Error processing country ASM: 0
# Error processing country ATG: 0
# Error processing country AUS: 0
# Error processing country AUT: 0
# Error processing country AZE: 0
# Error processing country BDI: 0
# Error processing country BEL: 0
# Error processing country BEN: 0
# Error processing country BFA: 0
# Error processing country BGD: 0
# Error processing country BGR: 0
# Error processing country BHR: 0
# Error processing country BHS: 0
# Error processing country BIH: 0
# Error processing country BLR: 0
# Error processing country BLZ: 0
# Error processing country BMU: 0
# Error processing country BOL: 0
# ...
